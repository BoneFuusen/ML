# %%
import pandas as pd

# %%
data = {'Name': ['Strom, Mrs. Wilhelm (Elna Matilda Persson)', 'Navratil, Mr. Michel ("Louis M Hoffman")',
                     'Minahan, Miss. Daisy E'],
            'Age': [29, 36.5, 33],
            'Sex': ['female', 'male', 'female']}

df = pd.DataFrame(data)
df
# Out:
#                                          Name   Age     Sex
# 0  Strom, Mrs. Wilhelm (Elna Matilda Persson)  29.0  female
# 1    Navratil, Mr. Michel ("Louis M Hoffman")  36.5    male
# 2                      Minahan, Miss. Daisy E  33.0  female

# %%
df_titanic = pd.read_csv('../data/titanic_csv.csv', sep=";")
df_titanic
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 0            454         1       1              Goldenberg, Mr. Samuel L
# 1            234         1       3        Asplund, Miss. Lillian Gertrud
# 2            556         0       1                    Wright, Mr. George
# 3            766         1       1  Hogeboom, Mrs. John C (Anna Andrews)
# 4            444         1       2             Reynaldo, Ms. Encarnacion
# ..           ...       ...     ...                                   ...
# 489          363         0       3       Barbara, Mrs. (Catherine David)
# 490          447         1       2     Mellinger, Miss. Madeleine Violet
# 491           95         0       3                     Coxon, Mr. Daniel
# 492           59         1       2          West, Miss. Constance Mirium
# 493           33         1       3              Glynn, Miss. Mary Agatha
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# ...

# %%
gist_df = pd.read_csv('https://gist.githubusercontent.com/zaryanezrya/8b4ef51c707cb16d5e88a44dc00a1bb2/raw/41230f49c6268e072dbf102672f670be256922ab/gistfile1.txt')
gist_df
# Out:
#      passengerid  survived  pclass  \
# 0            552         0       2
# 1            689         0       3
# 2            605         1       1
# 3            305         0       3
# 4            290         1       3
# ..           ...       ...     ...
# 495          482         0       2
# 496          155         0       3
# 497          851         0       3
# 498          850         1       1
# 499           77         0       3
#
#                                              name     sex   age  sibsp  parch  \
# 0                     Sharp, Mr. Percival James R    male  27.0      0      0
# 1                 Fischer, Mr. Eberhard Thelander    male  18.0      0      0
# 2                 Homer, Mr. Harry ("Mr E Haven")    male  35.0      0      0
# 3               Williams, Mr. Howard Hugh "Harry"    male   NaN      0      0
# 4                            Connolly, Miss. Kate  female  22.0      0      0
# ...

# %%
df_titanic.rename(str.lower, axis='columns', inplace=True)

df_concat = pd.concat([df_titanic, gist_df], ignore_index=True)

df_concat = df_concat.drop_duplicates()

df_concat
# Out:
#      passengerid  survived  pclass  \
# 0            454         1       1
# 1            234         1       3
# 2            556         0       1
# 3            766         1       1
# 4            444         1       2
# ..           ...       ...     ...
# 987          445         1       3
# 988          640         0       3
# 991          851         0       3
# 992          850         1       1
# 993           77         0       3
#
#                                              name     sex   age  sibsp  parch  \
# 0                        Goldenberg, Mr. Samuel L    male  49.0      1      0
# 1                  Asplund, Miss. Lillian Gertrud  female   5.0      4      2
# 2                              Wright, Mr. George    male  62.0      0      0
# 3            Hogeboom, Mrs. John C (Anna Andrews)  female  51.0      1      0
# 4                       Reynaldo, Ms. Encarnacion  female  28.0      0      0
# ...

# %%
df_concat = df_concat.set_index('passengerid')
df_concat = df_concat.sort_values(by='passengerid')
df_concat
# Out:
#              survived  pclass  \
# passengerid
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           name     sex   age  \
# passengerid
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   name      891 non-null    object
#  3   sex       891 non-null    object
#  4   age       714 non-null    float64
#  5   sibsp     891 non-null    int64
#  6   parch     891 non-null    int64
#  7   ticket    891 non-null    object
#  8   fare      891 non-null    float64
#  9   cabin     204 non-null    object
#  10  embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
df_concat.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
temp = df_concat.iloc[0].copy()
df_concat.iloc[0] = df_concat.loc[2]
df_concat.iloc[2] = temp
df_concat
# Out:
#              survived  pclass  \
# passengerid
# 1                   1       1
# 2                   1       1
# 3                   0       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           name     sex   age  \
# passengerid
# 1            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                      Braund, Mr. Owen Harris    male  22.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
replacement = {'female': 'f', 'male': 'm'}

df_concat['sex'] = df_concat['sex'].map(replacement)

# %%
filtered_tickets = df_concat.groupby(['ticket'])['ticket'].count()

filtered_tickets[filtered_tickets.values >= 6]
# Out:
# ticket
# 1601        7
# 3101295     6
# 347082      7
# 347088      6
# CA 2144     6
# CA. 2343    7
# Name: ticket, dtype: int64

# %%
df_concat[df_concat.cabin.isin(df_concat.loc[df_concat.name.isin(df.Name)].cabin)]
# Out:
#              survived  pclass  \
# passengerid
# 11                  1       3
# 149                 0       2
# 194                 1       2
# 206                 0       3
# 246                 0       1
# 252                 0       3
# 341                 1       2
# 395                 1       3
# 413                 1       1
#
#                                                           name sex   age  \
# passengerid
# 11                             Sandstrom, Miss. Marguerite Rut   f   4.0
# 149                   Navratil, Mr. Michel ("Louis M Hoffman")   m  36.5
# 194                                 Navratil, Master. Michel M   m   3.0
# 206                                 Strom, Miss. Telma Matilda   f   2.0
# 246                                Minahan, Dr. William Edward   m  44.0
# 252                 Strom, Mrs. Wilhelm (Elna Matilda Persson)   f  29.0
# 341                             Navratil, Master. Edmond Roger   m   2.0
# ...

# %%
df_concat['BirthYear'] = 1911 - df_concat.age

# %%
df_concat['Companion'] = df_concat.groupby('cabin')['name'].transform('count') - 1
df_concat
# Out:
#              survived  pclass  \
# passengerid
# 1                   1       1
# 2                   1       1
# 3                   0       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           name sex   age  \
# passengerid
# 1            Cumings, Mrs. John Bradley (Florence Briggs Th...   f  38.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...   f  38.0
# 3                                      Braund, Mr. Owen Harris   m  22.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)   f  35.0
# 5                                     Allen, Mr. William Henry   m  35.0
# ...                                                        ...  ..   ...
# ...

# %%
temp = df_concat.iloc[0].copy()
df_concat.iloc[0] = df_concat.loc[1]
df_concat.iloc[1] = temp

# %%
df_concat.to_csv("../data/titanic_modified.csv")

# %%
df_concat[['name', 'fare']].sort_values(by='fare', ascending=False).head(10)
# Out:
#                                                         name      fare
# passengerid
# 259                                         Ward, Miss. Anna  512.3292
# 738                                   Lesurer, Mr. Gustave J  512.3292
# 680                       Cardeza, Mr. Thomas Drake Martinez  512.3292
# 28                            Fortune, Mr. Charles Alexander  263.0000
# 342                           Fortune, Miss. Alice Elizabeth  263.0000
# 89                                Fortune, Miss. Mabel Helen  263.0000
# 439                                        Fortune, Mr. Mark  263.0000
# 743                    Ryerson, Miss. Susan Parker "Suzette"  262.3750
# 312                               Ryerson, Miss. Emily Borie  262.3750
# 300          Baxter, Mrs. James (Helene DeLaudeniere Chaput)  247.5208

# %%
df_concat.groupby(['sex', 'survived'])['sex'].count()
# Out:
# sex  survived
# f    0            81
#      1           233
# m    0           468
#      1           109
# Name: sex, dtype: int64

# %%
df_concat.groupby(['survived', 'pclass'])['survived'].count()
# Out:
# survived  pclass
# 0         1          80
#           2          97
#           3         372
# 1         1         137
#           2          87
#           3         118
# Name: survived, dtype: int64
